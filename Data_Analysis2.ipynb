# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:/Users/cmscomputers/Downloads/Skype/hitters.csv')

# %%
df
# Out:
#                  Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0       Andy Allanson    293    66      1    30   29     14      1     293
# 1          Alan Ashby    315    81      7    24   38     39     14    3449
# 2         Alvin Davis    479   130     18    66   72     76      3    1624
# 3        Andre Dawson    496   141     20    65   78     37     11    5628
# 4    Andres Galarraga    321    87     10    39   42     30      2     396
# ..                ...    ...   ...    ...   ...  ...    ...    ...     ...
# 317      Willie McGee    497   127      7    65   48     37      5    2703
# 318   Willie Randolph    492   136      5    76   50     94     12    5511
# 319    Wayne Tolleson    475   126      3    61   43     52      6    1700
# 320     Willie Upshaw    573   144      9    85   60     78      8    3198
# 321     Willie Wilson    631   170      9    77   44     31     11    4908
#
# ...

# %% [markdown]
# Scenario 1:
# Find of people who have batted for more than 400 matches

# %%
(df[(df['AtBat']>400) & (df['Name'])].iloc[:,0:2]).count()
# Out:
# Name     151
# AtBat    151
# dtype: int64

# %%
df[df.AtBat >400].Name.value_counts()
# Out:
# Mitch Webster        1
# Bobby Bonilla        1
# Spike Owen           1
# Jim Presley          1
# Darryl Strawberry    1
#                     ..
# Ken Oberkfell        1
# Billy Hatcher        1
# Larry Parrish        1
# Ray Knight           1
# Jody Davis           1
# Name: Name, Length: 151, dtype: int64

# %% [markdown]
# People batted more than 400 matches are 151.

# %% [markdown]
# Scenario 2:
# Find out the name of the player who has hit max home runs

# %%
df[df.HmRun==40].iloc[:,:4]
# Out:
#                Name  AtBat  Hits  HmRun
# 136  Jesse Barfield    589   170     40

# %% [markdown]
# Scenario 3:
# Find out league wise total number of players

# %%
df.groupby(by=['League']).count().iloc[:,0:1]
# Out:
#         Name
# League
# A        175
# N        147

# %% [markdown]
# Scenario 6:
# Find out division wise total amount of salary invested

# %%
df.groupby(by=['Division']).Salary.sum()
# Out:
# Division
# E    80531.006
# W    60417.501
# Name: Salary, dtype: float64

# %% [markdown]
# Scenario 10:
# Find out five most senior players.

# %%
(df.groupby(by=['Name']).Years.max().iloc[16:]).sort_values(ascending=False).head(5)
# Out:
# Name
# Pete Rose         24
# Tony Perez        23
# Graig Nettles     20
# Reggie Jackson    20
# Ted Simmons       19
# Name: Years, dtype: int64

# %% [markdown]
# # 2nd df

# %%
gog=pd.read_csv('C:/Users/cmscomputers/Downloads/Skype/Google_Stock_Price_Train.csv')

# %%
gog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   object
#  1   Open    1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Close   1258 non-null   float64
#  5   Volume  1258 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 59.1+ KB

# %% [markdown]
# Add 4 new columns to this dataframe, containing open, low, high, closing price in Rupees.(right now stock prices are in dollars)

# %%
new_gog=(gog.assign(openrs =lambda x: x.Open*75,highrs=lambda x: x.High*75,lowrs=lambda x: x.Low*75,closers=lambda x: x.Close*75))

# %%
new_gog
# Out:
#             Date    Open    High     Low   Close      Volume    openrs  \
# 0       1/3/2012  325.25  332.83  324.97  663.59   7380500.0  24393.75
# 1       1/4/2012  331.27  333.87  329.08  666.45   5749400.0  24845.25
# 2       1/5/2012  329.83  330.75  326.89  657.21   6590300.0  24737.25
# 3       1/6/2012  328.34  328.77  323.68  648.24   5405900.0  24625.50
# 4       1/9/2012  322.04  322.29  309.46  620.76  11688800.0  24153.00
# ...          ...     ...     ...     ...     ...         ...       ...
# 1253  12/23/2016  790.90  792.74  787.28  789.91    623400.0  59317.50
# 1254  12/27/2016  790.68  797.86  787.66  791.55    789100.0  59301.00
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1153800.0  59527.50
# 1256  12/29/2016  783.33  785.93  778.92  782.79    744300.0  58749.75
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1770000.0  58706.25
#
#         highrs     lowrs   closers
# 0     24962.25  24372.75  49769.25
# 1     25040.25  24681.00  49983.75
# ...

# %% [markdown]
# # 3rd df

# %%
imd=pd.read_csv('C:/Users/cmscomputers/Downloads/Skype/IMDB-Movie-Data.csv')

# %%
imd.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# Filter out all action movies

# %%
#imd2=imd.Genre.str.split(',',expand=True)
#imd2.columns=['genre1','genre2','genre3']
#imd2

# %%
#imd=pd.concat([imd,imd2],axis=1)

# %%
imd.info()

# %%
(imd[imd['Genre'].str.contains('Action',case=False)])
# Out:
#      Rank                           Title                       Genre  \
# 0       1         Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 4       5                   Suicide Squad    Action,Adventure,Fantasy
# 5       6                  The Great Wall    Action,Adventure,Fantasy
# 8       9              The Lost City of Z  Action,Adventure,Biography
# 12     13                       Rogue One     Action,Adventure,Sci-Fi
# ..    ...                             ...                         ...
# 958   959                  3 Days to Kill       Action,Drama,Thriller
# 968   969                         Wrecker      Action,Horror,Thriller
# 969   970                 The Lone Ranger    Action,Adventure,Western
# 990   991  Underworld: Rise of the Lycans    Action,Adventure,Fantasy
# 993   994        Resident Evil: Afterlife     Action,Adventure,Horror
#
#                                            Description            Director  \
# ...

# %% [markdown]
# # 4th dataset

# %%
ecom=pd.read_csv('C:/Users/cmscomputers/Downloads/Skype/ecommerce.csv')

# %%
ecom.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %%
ecom.info()

# %% [markdown]
# Find out total puchases made by each customer.

# %%
ecom2=(ecom.groupby(by='CustomerID').Quantity.count())
ecom2
# Out:
# CustomerID
# 12346.0      2
# 12347.0    182
# 12348.0     31
# 12349.0     73
# 12350.0     17
#           ...
# 18280.0     10
# 18281.0      7
# 18282.0     13
# 18283.0    756
# 18287.0     70
# Name: Quantity, Length: 4372, dtype: int64

# %% [markdown]
# Find out top 20 customers based on number of purchases made

# %%
ecom2.sort_values(ascending=False).head(20)
# Out:
# CustomerID
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
# 15311.0    2491
# 14646.0    2085
# 13089.0    1857
# 13263.0    1677
# 14298.0    1640
# 15039.0    1508
# 14156.0    1420
# 18118.0    1284
# 14159.0    1212
# 14796.0    1165
# 15005.0    1160
# 16033.0    1152
# 14056.0    1128
# 14769.0    1094
# 17511.0    1076
# Name: Quantity, dtype: int64

# %% [markdown]
# # 5th dataset

# %%
cre=pd.read_csv('C:/Users/cmscomputers/Downloads/Skype/Credit.csv')

# %%
cre.head()
# Out:
#    Unnamed: 0  ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0           1   1   14.891   3606     283      2   34         11    Male
# 1           2   2  106.025   6645     483      3   82         15  Female
# 2           3   3  104.593   7075     514      4   71         11    Male
# 3           4   4  148.924   9504     681      3   36         11  Female
# 4           5   5   55.882   4897     357      2   68         16    Male
#
#   Student Married  Ethnicity  Balance
# 0      No     Yes  Caucasian      333
# 1     Yes     Yes      Asian      903
# 2      No      No      Asian      580
# 3      No      No      Asian      964
# 4      No     Yes  Caucasian      331

# %% [raw]
# Create a new column class on the basis of income of the candidates
# 0-50 Poor
# 50-100 Middle
# 100-150 Upper_Middle
# 150+ Rich_affluent

# %%
cre['Income'].sort_values()
# Out:
# 58      10.354
# 250     10.363
# 199     10.403
# 235     10.503
# 262     10.588
#         ...
# 275    163.329
# 261    180.379
# 355    180.682
# 323    182.728
# 28     186.634
# Name: Income, Length: 400, dtype: float64

# %%
q =[]
for i in cre['Income']:
    if(i <=50):
        q.append('Poor')
    elif(i <=100):
        q.append('Middle')
    elif(i <=150):
        q.append('Upper_Middle')
    else:
        q.append('Rich_affluent')

# %%
cre['class']=q

# %%
cre.head(15)
# Out:
#     Unnamed: 0  ID   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0            1   1   14.891   3606     283      2   34         11    Male
# 1            2   2  106.025   6645     483      3   82         15  Female
# 2            3   3  104.593   7075     514      4   71         11    Male
# 3            4   4  148.924   9504     681      3   36         11  Female
# 4            5   5   55.882   4897     357      2   68         16    Male
# 5            6   6   80.180   8047     569      4   77         10    Male
# 6            7   7   20.996   3388     259      2   37         12  Female
# 7            8   8   71.408   7114     512      2   87          9    Male
# 8            9   9   15.125   3300     266      5   66         13  Female
# 9           10  10   71.061   6819     491      3   41         19  Female
# 10          11  11   63.095   8117     589      4   30         14    Male
# 11          12  12   15.045   1311     138      3   64         16    Male
# ...

# %% [markdown]
# # 6th Dataset

# %%
md=pd.read_csv('C:/Users/cmscomputers/Downloads/Skype/mcdonalds.csv')

# %%
md.head()
# Out:
#           Date        Item  Quantity
# 0  12-Jun-2020  Aloo tikki         2
# 1  12-Jun-2020    McVeggie         1
# 2  12-Jun-2020        Chai         2
# 3  12-Jun-2020    McVeggie         1
# 4  12-Jun-2020       Fries         2

# %% [markdown]
#  Find out date wise total number of aloo tikkis sold.

# %%
m=md[md.Item=='Aloo tikki']

# %%
m.groupby(by=['Date'])['Quantity'].sum()
# Out:
# Date
# 12-Jun-2020     2
# 13-Jun-2020    18
# Name: Quantity, dtype: int64
