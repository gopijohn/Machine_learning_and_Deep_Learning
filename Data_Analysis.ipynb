# %%
import pandas as pd

# %%
A=pd.read_csv('C:/Users/cmscomputers/Downloads/Skype/Datasets/Cars93.csv')

# %%
A.head(3)
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                None  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
#
#    Turn.circle  Rear.seat.room Luggage.room  Weight   Origin           Make
# 0           37            26.5         11.0    2705  non-USA  Acura Integra
# 1           38            30.0         15.0    3560  non-USA   Acura Legend
# 2           37            28.0         14.0    3375  non-USA        Audi 90
#
# [3 rows x 28 columns]

# %%
A.tail(3)
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 90           25                None  ...          4    159         97     66
# 91           28         Driver only  ...          5    190        104     67
# 92           28  Driver & Passenger  ...          5    184        105     69
#
#     Turn.circle  Rear.seat.room Luggage.room  Weight   Origin  \
# 90           36            26.0         15.0    2810  non-USA
# 91           37            29.5         14.0    2985  non-USA
# 92           38            30.0         15.0    3245  non-USA
#
#                   Make
# 90  Volkswagen Corrado
# 91           Volvo 240
# ...

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             89 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
# ...

# %% [markdown]
# Specific column fetching

# %%
A[['Passengers','Model','Price']]
# Out:
#     Passengers    Model  Price
# 0            5  Integra   15.9
# 1            5   Legend   33.9
# 2            5       90   29.1
# 3            6      100   37.7
# 4            4     535i   30.0
# ..         ...      ...    ...
# 88           7  Eurovan   19.7
# 89           5   Passat   20.0
# 90           4  Corrado   23.3
# 91           5      240   22.7
# 92           5      850   26.7
#
# [93 rows x 3 columns]

# %% [markdown]
# conditional Filtering

# %%
A[A.Type=='Compact']
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 2    3           Audi        90  Compact       25.9   29.1       32.3
# 11  12      Chevrolet  Cavalier  Compact        8.5   13.4       18.3
# 12  13      Chevrolet   Corsica  Compact       11.4   11.4       11.4
# 20  21       Chrysler   LeBaron  Compact       14.5   15.8       17.1
# 24  25          Dodge    Spirit  Compact       11.9   13.3       14.7
# 32  33           Ford     Tempo  Compact       10.4   11.3       12.2
# 42  43          Honda    Accord  Compact       13.8   17.5       21.2
# 54  55          Mazda       626  Compact       14.3   16.5       18.7
# 57  58  Mercedes-Benz      190E  Compact       29.0   31.9       34.9
# 64  65         Nissan    Altima  Compact       13.0   15.7       18.3
# 67  68     Oldsmobile   Achieva  Compact       13.0   13.5       14.0
# 73  74        Pontiac   Sunbird  Compact        9.4   11.1       12.8
# ...

# %%
A[A.Type=='Sporty']
# Out:
#     id Manufacturer     Model    Type  Min.Price  Price  Max.Price  MPG.city  \
# 13  14    Chevrolet    Camaro  Sporty       13.4   15.1       16.8        19
# 18  19    Chevrolet  Corvette  Sporty       34.6   38.0       41.5        17
# 27  28        Dodge   Stealth  Sporty       18.5   25.8       33.1        18
# 33  34         Ford   Mustang  Sporty       10.8   15.9       21.0        22
# 34  35         Ford     Probe  Sporty       12.8   14.0       15.2        24
# 39  40          Geo     Storm  Sporty       11.5   12.5       13.5        30
# 40  41        Honda   Prelude  Sporty       17.0   19.8       22.7        24
# 45  46      Hyundai    Scoupe  Sporty        9.1   10.0       11.0        26
# 56  57        Mazda      RX-7  Sporty       32.5   32.5       32.5        17
# 59  60      Mercury     Capri  Sporty       13.3   14.1       15.0        23
# 71  72     Plymouth     Laser  Sporty       11.4   14.4       17.4        23
# ...

# %%
A[A.Manufacturer=='Ford']
# Out:
#     id Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 30  31         Ford         Festiva    Small        6.9    7.4        7.9
# 31  32         Ford          Escort    Small        8.4   10.1       11.9
# 32  33         Ford           Tempo  Compact       10.4   11.3       12.2
# 33  34         Ford         Mustang   Sporty       10.8   15.9       21.0
# 34  35         Ford           Probe   Sporty       12.8   14.0       15.2
# 35  36         Ford        Aerostar      Van       14.5   19.9       25.3
# 36  37         Ford          Taurus  Midsize       15.6   20.2       24.8
# 37  38         Ford  Crown_Victoria    Large       20.1   20.9       21.7
#
#     MPG.city  MPG.highway      AirBags  ... Passengers Length  Wheelbase  \
# 30        31           33         None  ...          4    141         90
# 31        23           30         None  ...          5    171         98
# 32        22           27         None  ...          5    177        100
# ...

# %% [markdown]
# Cars with length more than 150

# %%
A[A.Length >200].sort_values(by='Length')
# Out:
#     id Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 70  71   Oldsmobile    Eighty-Eight    Large       19.5   20.7       21.9
# 29  30        Eagle          Vision    Large       17.5   19.3       21.2
# 19  20     Chrylser        Concorde    Large       18.4   18.4       18.4
# 21  22     Chrysler        Imperial    Large       29.5   29.5       29.5
# 10  11     Cadillac         Seville  Midsize       37.5   40.1       42.7
# 50  51      Lincoln     Continental  Midsize       33.3   34.3       35.3
# 9   10     Cadillac         DeVille    Large       33.0   34.7       36.3
# 37  38         Ford  Crown_Victoria    Large       20.1   20.9       21.7
# 17  18    Chevrolet         Caprice    Large       18.0   18.8       19.6
# 7    8        Buick      Roadmaster    Large       22.6   23.7       24.9
# 51  52      Lincoln        Town_Car    Large       34.4   36.1       37.8
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# ...

# %% [markdown]
# Cars of Lincoln and price more than 30

# %%
A[(A.Manufacturer=='Lincoln') & (A.Price>30)]
# Out:
#     id Manufacturer        Model     Type  Min.Price  Price  Max.Price  \
# 50  51      Lincoln  Continental  Midsize       33.3   34.3       35.3
# 51  52      Lincoln     Town_Car    Large       34.4   36.1       37.8
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 50        17           26  Driver & Passenger  ...          6    205
# 51        18           26                 NaN  ...          6    219
#
#     Wheelbase  Width  Turn.circle  Rear.seat.room Luggage.room  Weight  \
# 50        109     73           42            30.0         19.0    3695
# 51        117     77           45            31.5         22.0    4055
#
#     Origin                 Make
# 50     USA  Lincoln Continental
# 51     USA     Lincoln Town_Car
#
# [2 rows x 28 columns]

# %% [markdown]
# Aggregate functions

# %%
A.Price.max()
# Out:
# 61.9

# %%
A.Length.min()
# Out:
# 141

# %%
A.Length.mean()
# Out:
# 183.20430107526883

# %%
A.Price.sum()
# Out:
# 1814.4

# %% [markdown]
# Grouping

# %%
A.groupby(by='Manufacturer').Price.min()
# Out:
# Manufacturer
# Acura            15.9
# Audi             29.1
# BMW              30.0
# Buick            15.7
# Cadillac         34.7
# Chevrolet        11.4
# Chrylser         18.4
# Chrysler         15.8
# Dodge             9.2
# Eagle            12.2
# Ford              7.4
# Geo               8.4
# Honda            12.1
# Hyundai           8.0
# Infiniti         47.9
# Lexus            28.0
# Lincoln          34.3
# Mazda             8.3
# Mercedes-Benz    31.9
# Mercury          14.1
# Mitsubishi       10.3
# Nissan           11.8
# Oldsmobile       13.5
# Plymouth         14.4
# Pontiac           9.0
# Saab             28.7
# Saturn           11.1
# Subaru            8.4
# Suzuki            8.6
# Toyota            9.8
# Volkswagen        9.1
# Volvo            22.7
# Name: Price, dtype: float64

# %%
A.groupby(by='Model').Price.max()
# Out:
# Model
# 100         37.7
# 190E        31.9
# 240         22.7
# 300E        61.9
# 323          8.3
#             ...
# Taurus      20.2
# Tempo       11.3
# Tercel       9.8
# Town_Car    36.1
# Vision      19.3
# Name: Price, Length: 93, dtype: float64

# %%
A.groupby(by='Type').Wheelbase.max()
# Out:
# Type
# Compact    107
# Large      117
# Midsize    115
# Small      103
# Sporty     103
# Van        119
# Name: Wheelbase, dtype: int64

# %%
A[['Fuel.tank.capacity']]
# Out:
#     Fuel.tank.capacity
# 0                 13.2
# 1                 18.0
# 2                 16.9
# 3                 21.1
# 4                 21.1
# ..                 ...
# 88                21.1
# 89                18.5
# 90                18.5
# 91                15.8
# 92                19.3
#
# [93 rows x 1 columns]
